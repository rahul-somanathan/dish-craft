# %% [markdown]
# # Environment Setup

# %% [markdown]
# ## Import Libraries

# %%
# Importing necessary libraries

import pandas as pd

# %% [markdown]
# ## Load Dataset

# %%
# Loading raw recipe and interactions data

df_recipes = pd.read_csv('../data/raw/RAW_recipes.csv')
df_interactions = pd.read_csv('../data/raw/RAW_interactions.csv')
df_luigi_preferences = pd.read_csv('../data/raw/luigi_preferences.csv')

# %%
# Checking the dataframe for recipes

df_recipes.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8

# %%
# Checking the dataframe for interactions

df_interactions.head()
# Out:
#    user_id  recipe_id        date  rating  \
# 0    38094      40893  2003-02-17       4
# 1  1293707      40893  2011-12-21       5
# 2     8937      44394  2002-12-01       4
# 3   126440      85009  2010-02-27       5
# 4    57222      85009  2011-10-01       5
#
#                                               review
# 0  Great with a salad. Cooked on top of stove for...
# 1  So simple, so delicious! Great for chilly fall...
# 2  This worked very well and is EASY.  I used not...
# 3  I made the Mexican topping and took it to bunk...
# 4  Made the cheddar bacon topping, adding a sprin...

# %%
# Checking the dataframe for luigi preferences

df_luigi_preferences.head()
# Out:
#    User ID  Age Nationality Residence Cuisine Preference     Recipe Selection
# 0        1   26     Italian    Canada            Italian       Lasagna, Pizza
# 1        2   26     Italian    Canada            Italian  Spaghetti Carbonara
# 2        3   26     Italian    Canada            Italian             Tiramisù
# 3        4   26     Italian    Canada            Italian              Risotto
# 4        5   26     Italian    Canada            Italian          Panna Cotta

# %% [markdown]
# # Data Information

# %%
# Viewing interaction data info

df_interactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1132367 entries, 0 to 1132366
# Data columns (total 5 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   user_id    1132367 non-null  int64
#  1   recipe_id  1132367 non-null  int64
#  2   date       1132367 non-null  object
#  3   rating     1132367 non-null  int64
#  4   review     1132198 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 43.2+ MB

# %%
# Viewing recipe data info

df_recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231637 entries, 0 to 231636
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            231636 non-null  object
#  1   id              231637 non-null  int64
#  2   minutes         231637 non-null  int64
#  3   contributor_id  231637 non-null  int64
#  4   submitted       231637 non-null  object
#  5   tags            231637 non-null  object
#  6   nutrition       231637 non-null  object
#  7   n_steps         231637 non-null  int64
#  8   steps           231637 non-null  object
#  9   description     226658 non-null  object
#  10  ingredients     231637 non-null  object
#  11  n_ingredients   231637 non-null  int64
# dtypes: int64(5), object(7)
# memory usage: 21.2+ MB

# %%
# Viewing luigi preference data

df_luigi_preferences.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   User ID             15 non-null     int64
#  1   Age                 15 non-null     int64
#  2   Nationality         15 non-null     object
#  3   Residence           15 non-null     object
#  4   Cuisine Preference  15 non-null     object
#  5   Recipe Selection    15 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 852.0+ bytes

# %%
# Viewing recipe and interactions data shape

df_recipes.shape, df_interactions.shape
# Out:
# ((231637, 12), (1132367, 5))

# %%
# Viewing luigi preference data shape

df_luigi_preferences.shape
# Out:
# (15, 6)

# %% [markdown]
# # Data Aggregation

# %%
# Joining recipe and interactions data

df_aggregated = df_interactions.merge(
    df_recipes, left_on="recipe_id", right_on="id", how='left')
df_aggregated.drop(columns=["id"], inplace=True)
df_aggregated = df_aggregated.dropna(subset=["name", "minutes", "contributor_id", "submitted",
                                     "tags", "nutrition", "n_steps", "steps", "description", "ingredients", "n_ingredients"])
df_aggregated.shape
# Out:
# (1108856, 16)

# %%
# Verifying aggregated dataset

df_aggregated.head()
# Out:
#    user_id  recipe_id        date  rating  \
# 0    38094      40893  2003-02-17       4
# 1  1293707      40893  2011-12-21       5
# 3   126440      85009  2010-02-27       5
# 4    57222      85009  2011-10-01       5
# 5    52282     120345  2005-05-21       4
#
#                                               review  \
# 0  Great with a salad. Cooked on top of stove for...
# 1  So simple, so delicious! Great for chilly fall...
# 3  I made the Mexican topping and took it to bunk...
# 4  Made the cheddar bacon topping, adding a sprin...
# 5  very very sweet. after i waited the 2 days i b...
#
#                                    name  minutes  contributor_id   submitted  \
# 0  white bean   green chile pepper soup      495            1533  2002-09-21
# 1  white bean   green chile pepper soup      495            1533  2002-09-21
# 3                 baked potato toppings       10           64342  2004-02-25
# 4                 baked potato toppings       10           64342  2004-02-25
# 5                   sugared raspberries       10           37449  2005-05-02
#
#                                                 tags  \
# 0  ['weeknight', 'time-to-make', 'course', 'main-...
# 1  ['weeknight', 'time-to-make', 'course', 'main-...
# 3  ['15-minutes-or-less', 'time-to-make', 'course...
# 4  ['15-minutes-or-less', 'time-to-make', 'course...
# 5  ['15-minutes-or-less', 'time-to-make', 'course...
#
#                                            nutrition  n_steps  \
# 0           [204.8, 5.0, 9.0, 26.0, 24.0, 2.0, 10.0]        4
# 1           [204.8, 5.0, 9.0, 26.0, 24.0, 2.0, 10.0]        4
# 3  [2786.2, 342.0, 134.0, 290.0, 161.0, 301.0, 42.0]        3
# 4  [2786.2, 342.0, 134.0, 290.0, 161.0, 301.0, 42.0]        3
# 5           [838.0, 1.0, 820.0, 0.0, 2.0, 0.0, 71.0]        6
#
#                                                steps  \
# 0  ['combine beans , onion , chilies , 1 / 2 teas...
# 1  ['combine beans , onion , chilies , 1 / 2 teas...
# 3  ['pick whichever topping you want to use and c...
# 4  ['pick whichever topping you want to use and c...
# 5  ['carefully pick over the berries , removing l...
#
#                                          description  \
# 0                        easy soup for the crockpot.
# 1                        easy soup for the crockpot.
# 3  these toppings sure makes a nice change from p...
# 4  these toppings sure makes a nice change from p...
# 5  here's an old method for preserving fruit with...
#
#                                          ingredients  n_ingredients
# 0  ['great northern beans', 'yellow onion', 'dice...              9
# 1  ['great northern beans', 'yellow onion', 'dice...              9
# 3  ['mayonnaise', 'salsa', 'cheddar cheese', 'ref...             13
# 4  ['mayonnaise', 'salsa', 'cheddar cheese', 'ref...             13
# 5                ['raspberries', 'granulated sugar']              2

# %%
# Convert columns to datetime for better processing

df_aggregated[["date", "submitted"]] = df_aggregated[[
    "date", "submitted"]].apply(pd.to_datetime)

# %%
# Verifying dtypes of converted columns with datetime

df_aggregated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1108856 entries, 0 to 1132366
# Data columns (total 16 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   user_id         1108856 non-null  int64
#  1   recipe_id       1108856 non-null  int64
#  2   date            1108856 non-null  datetime64[ns]
#  3   rating          1108856 non-null  int64
#  4   review          1108688 non-null  object
#  5   name            1108856 non-null  object
#  6   minutes         1108856 non-null  int64
#  7   contributor_id  1108856 non-null  int64
#  8   submitted       1108856 non-null  datetime64[ns]
#  9   tags            1108856 non-null  object
#  10  nutrition       1108856 non-null  object
#  11  n_steps         1108856 non-null  int64
#  12  steps           1108856 non-null  object
#  13  description     1108856 non-null  object
#  14  ingredients     1108856 non-null  object
#  15  n_ingredients   1108856 non-null  int64
# dtypes: datetime64[ns](2), int64(7), object(7)
# memory usage: 143.8+ MB

# %%
df_luigi_preferences.drop(['User ID','Age','Nationality','Residence','Cuisine Preference'], axis=1,inplace = True)
df_luigi_preferences
# Out:
#        Recipe Selection
# 0        Lasagna, Pizza
# 1   Spaghetti Carbonara
# 2              Tiramisù
# 3               Risotto
# 4           Panna Cotta
# 5               Gnocchi
# 6               Ravioli
# 7             Osso Buco
# 8       Minestrone Soup
# 9               Cannoli
# 10        Caprese Salad
# 11             Biscotti
# 12             Focaccia
# 13             Ossobuco
# 14  Eggplant Parmigiana

# %%
df_luigi_preferences_formatted = df_luigi_preferences["Recipe Selection"].str.split(",", expand=True).stack().reset_index(level=1, drop=True).to_frame("Recipe Selection").reset_index(drop=True)
df_luigi_preferences_formatted
# Out:
#        Recipe Selection
# 0               Lasagna
# 1                 Pizza
# 2   Spaghetti Carbonara
# 3              Tiramisù
# 4               Risotto
# 5           Panna Cotta
# 6               Gnocchi
# 7               Ravioli
# 8             Osso Buco
# 9       Minestrone Soup
# 10              Cannoli
# 11        Caprese Salad
# 12             Biscotti
# 13             Focaccia
# 14             Ossobuco
# 15  Eggplant Parmigiana

# %%
from fuzzywuzzy import process, fuzz


def get_closest_recipe_name(target_name):
    # Find the closest matching recipe name in the dataset
    closest_match = process.extractOne(target_name, df_recipes['name'], scorer=fuzz.token_set_ratio)
    closest_name = closest_match[0] if closest_match else None
    return closest_name

def get_recipe_id_by_name(recipe_name):
    # Find the closest matching recipe name in the dataset
    closest_name = get_closest_recipe_name(recipe_name)
    recipe_id = df_recipes[df_recipes['name'].str.lower() == closest_name.lower()]['id'].values
    if recipe_id.size == 0:
        print(f"No recipe found for name: {closest_name}")
        return None
    return recipe_id[0]

# %%
import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed

# Example DataFrame (replace with your actual DataFrame)
df_luigi_preferences_formatted = pd.DataFrame({
    'Recipe Selection': ['Recipe1', 'Recipe2', 'Recipe3']  # Replace with actual data
})

def process_row(pref_row):
    try:
        # Find the closest matching recipe name and corresponding ID in the original dataset
        closest_name = get_closest_recipe_name(pref_row['Recipe Selection'])
        recipe_id = get_recipe_id_by_name(closest_name)

        # Return the new data with updated name and ID
        return {
            'user_id': 121,  # Placeholder for user ID
            'recipe_id': recipe_id,
            'date': datetime.datetime(2017, 1, 1),  # Placeholder for date
            'rating': 5,  # Placeholder for rating
            'review': "Super",  # Placeholder for review
            'name': closest_name,
            'minutes': 10,  # Placeholder for minutes
            'contributor_id': None,  # Placeholder for contributor ID
            'submitted': datetime.datetime(2017, 1, 1),  # Placeholder for submitted
            'tags': "Italian",  # Placeholder for tags
            'nutrition': None,  # Placeholder for nutrition
            'n_steps': 10,  # Placeholder for number of steps
            'steps': "asdf",  # Placeholder for steps
            'description': "Good",  # Placeholder for description
            'ingredients': "Don't know",  # Placeholder for ingredients
        }
    except Exception as e:
        print(f"Error processing row: {pref_row}")
        print(f"Error message: {e}")
        return None

# Initialize lists to hold the new data to be appended
new_data = []

# Use ThreadPoolExecutor to parallelize the processing
with ThreadPoolExecutor(max_workers=4) as executor:
    # Submit all tasks to the executor
    future_to_row = {executor.submit(process_row, row): row for _, row in df_luigi_preferences_formatted.iterrows()}

    # Process the results as they complete
    for future in as_completed(future_to_row):
        result = future.result()
        if result:
            new_data.append(result)

# Output the new data
print(new_data)
# Out:
# Original Name: Recipe3
# Closest Name: eclipse
# Recipe ID: 22366
# Original Name: Recipe2
# Closest Name: eclipse
# Recipe ID: 22366
# Original Name: Recipe1
# Closest Name: eclipse
# Recipe ID: 22366
# [{'user_id': 121, 'recipe_id': 22366, 'date': datetime.datetime(2017, 1, 1, 0, 0), 'rating': 5, 'review': 'Super', 'name': 'eclipse', 'minutes': 10, 'contributor_id': None, 'submitted': datetime.datetime(2017, 1, 1, 0, 0), 'tags': 'Italian', 'nutrition': None, 'n_steps': 10, 'steps': 'asdf', 'description': 'Good', 'ingredients': "Don't know"}, {'user_id': 121, 'recipe_id': 22366, 'date': datetime.datetime(2017, 1, 1, 0, 0), 'rating': 5, 'review': 'Super', 'name': 'eclipse', 'minutes': 10, 'contributor_id': None, 'submitted': datetime.datetime(2017, 1, 1, 0, 0), 'tags': 'Italian', 'nutrition': None, 'n_steps': 10, 'steps': 'asdf', 'description': 'Good', 'ingredients': "Don't know"}, {'user_id': 121, 'recipe_id': 22366, 'date': datetime.datetime(2017, 1, 1, 0, 0), 'rating': 5, 'review': 'Super', 'name': 'eclipse', 'minutes': 10, 'contributor_id': None, 'submitted': datetime.datetime(2017, 1, 1, 0, 0), 'tags': 'Italian', 'nutrition': None, 'n_steps': 10, 'steps': 'asdf', 'description': 'Good', 'ingredients': "Don't know"}]

# %%
# Initialize lists to hold the new data to be appended
import datetime

new_data = []

count = 1
total = len(df_luigi_preferences_formatted)

# Iterate over the preference dataset
for _, pref_row in df_luigi_preferences_formatted.iterrows():
    try:
        # Find the closest matching recipe name and corresponding ID in the original dataset
        closest_name = get_closest_recipe_name(pref_row['Recipe Selection'])
        recipe_id = get_recipe_id_by_name(closest_name)

        print("Original Name:", pref_row['Recipe Selection'])
        print("Closest Name:", closest_name)
        print("Recipe ID:", recipe_id)

        print(f'Processing: {count}/{total}')

        # Append new data with updated name and ID
        new_data.append({
            'user_id': 121,  # Placeholder for user ID
            'recipe_id': recipe_id,
            'date': datetime.datetime(2017, 1, 1),  # Placeholder for date
            'rating': 5,  # Placeholder for rating
            'review': "Super",  # Placeholder for review
            'name': closest_name,
            'minutes': 10,  # Placeholder for minutes
            'contributor_id': None,  # Placeholder for contributor ID
            'submitted': datetime.datetime(2017, 1, 1),  # Placeholder for submitted
            'tags': "Italian",  # Placeholder for tags
            'nutrition': None,  # Placeholder for nutrition
            'n_steps': 10,  # Placeholder for number of steps
            'steps': "asdf",  # Placeholder for steps
            'description': "Good",  # Placeholder for description
            'ingredients': "Don't know",  # Placeholder for
        })
    except Exception as e:
        print(f"Error processing row: {pref_row}")
        print(f"Error message: {e}")

    count += 1
# Out:
# Original Name: Lasagna
# Closest Name: killer  lasagna
# Recipe ID: 53402
# Processing: 1/16
# Original Name:  Pizza
# Closest Name: a bit different  breakfast pizza
# Recipe ID: 31490
# Processing: 2/16
# Original Name: Spaghetti Carbonara
# Closest Name: alexander s spaghetti carbonara
# Recipe ID: 25400
# Processing: 3/16
# Original Name: Tiramisù
# Closest Name: easy pudding tiramis
# Recipe ID: 79063
# Processing: 4/16
# Original Name: Risotto
# Closest Name: beat the blues  blue cheese risotto
# Recipe ID: 137701
# Processing: 5/16
# Original Name: Panna Cotta
# Closest Name: buttermilk panna cotta
# Recipe ID: 206583
# Processing: 6/16
# Original Name: Gnocchi
# Closest Name: coal miners  gnocchi
# Recipe ID: 474769
# Processing: 7/16
# Original Name: Ravioli
# Closest Name: mamma mia  ravioli bites
# Recipe ID: 407516
# Processing: 8/16
# Original Name: Osso Buco
# Closest Name: chicken osso buco
# Recipe ID: 61152
# Processing: 9/16
# Original Name: Minestrone Soup
# Closest Name: another minestrone soup for crock pot
# Recipe ID: 46092
# Processing: 10/16
# Original Name: Cannoli
# Closest Name: baked cannoli pie
# Recipe ID: 197825
# Processing: 11/16
# Original Name: Caprese Salad
# Closest Name: baked caprese salad
# Recipe ID: 193072
# Processing: 12/16
# Original Name: Biscotti
# Closest Name: chocolate  cherry pecan biscotti
# Recipe ID: 220237
# Processing: 13/16
# Original Name: Focaccia
# Closest Name: artichoke  tomato and asiago focaccia
# Recipe ID: 283082
# Processing: 14/16
# Original Name: Ossobuco
# Closest Name: ossobuco al forno   baked veal shanks
# Recipe ID: 456730
# Processing: 15/16
# Original Name: Eggplant Parmigiana
# Closest Name: easy eggplant  aubergine  parmigiana
# Recipe ID: 60022
# Processing: 16/16

# %%
# Create a DataFrame from the new data
new_data_df = pd.DataFrame(new_data)

new_data_df
# Out:
#     user_id  recipe_id       date  rating review  \
# 0       121      53402 2017-01-01       5  Super
# 1       121      31490 2017-01-01       5  Super
# 2       121      25400 2017-01-01       5  Super
# 3       121      79063 2017-01-01       5  Super
# 4       121     137701 2017-01-01       5  Super
# 5       121     206583 2017-01-01       5  Super
# 6       121     474769 2017-01-01       5  Super
# 7       121     407516 2017-01-01       5  Super
# 8       121      61152 2017-01-01       5  Super
# 9       121      46092 2017-01-01       5  Super
# 10      121     197825 2017-01-01       5  Super
# 11      121     193072 2017-01-01       5  Super
# 12      121     220237 2017-01-01       5  Super
# 13      121     283082 2017-01-01       5  Super
# 14      121     456730 2017-01-01       5  Super
# 15      121      60022 2017-01-01       5  Super
#
#                                      name  minutes contributor_id  submitted  \
# 0                         killer  lasagna       10           None 2017-01-01
# 1        a bit different  breakfast pizza       10           None 2017-01-01
# 2         alexander s spaghetti carbonara       10           None 2017-01-01
# 3                    easy pudding tiramis       10           None 2017-01-01
# 4     beat the blues  blue cheese risotto       10           None 2017-01-01
# 5                  buttermilk panna cotta       10           None 2017-01-01
# 6                    coal miners  gnocchi       10           None 2017-01-01
# 7                mamma mia  ravioli bites       10           None 2017-01-01
# 8                       chicken osso buco       10           None 2017-01-01
# 9   another minestrone soup for crock pot       10           None 2017-01-01
# 10                      baked cannoli pie       10           None 2017-01-01
# 11                    baked caprese salad       10           None 2017-01-01
# 12       chocolate  cherry pecan biscotti       10           None 2017-01-01
# 13  artichoke  tomato and asiago focaccia       10           None 2017-01-01
# 14  ossobuco al forno   baked veal shanks       10           None 2017-01-01
# 15   easy eggplant  aubergine  parmigiana       10           None 2017-01-01
#
#        tags nutrition  n_steps steps description ingredients
# 0   Italian      None       10  asdf        Good  Don't know
# 1   Italian      None       10  asdf        Good  Don't know
# 2   Italian      None       10  asdf        Good  Don't know
# 3   Italian      None       10  asdf        Good  Don't know
# 4   Italian      None       10  asdf        Good  Don't know
# 5   Italian      None       10  asdf        Good  Don't know
# 6   Italian      None       10  asdf        Good  Don't know
# 7   Italian      None       10  asdf        Good  Don't know
# 8   Italian      None       10  asdf        Good  Don't know
# 9   Italian      None       10  asdf        Good  Don't know
# 10  Italian      None       10  asdf        Good  Don't know
# 11  Italian      None       10  asdf        Good  Don't know
# 12  Italian      None       10  asdf        Good  Don't know
# 13  Italian      None       10  asdf        Good  Don't know
# 14  Italian      None       10  asdf        Good  Don't know
# 15  Italian      None       10  asdf        Good  Don't know

# %%
# Concatenate the new data DataFrame with the original DataFrame
df_aggregated = pd.concat([df_aggregated, new_data_df], ignore_index=True)

# %% [markdown]
# # Filter data to 3 year prior to latest data

# %%
# Getting the latest entry for the reviews and 3 year prior to that

latest_date = df_aggregated["date"].max()
three_years_ago = latest_date - pd.DateOffset(years=3)

# %%
# Filtering data for the last 3 years data for ease of processing

df_filtered = df_aggregated[df_aggregated["date"] > three_years_ago]
df_filtered.reset_index(drop=True, inplace=True)
df_filtered.shape
# Out:
# (65620, 16)

# %% [markdown]
# # Exporting the data

# %%
# exporting the filtered data

df_filtered.to_pickle('../data/processed/df_filtered.pkl')

# %%
# exporting luigi preference data

df_luigi_preferences.to_pickle('../data/processed/df_luigi_preferences.pkl')
